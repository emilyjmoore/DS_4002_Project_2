# %%
# Import necessary packages
import matplotlib.pyplot as plt
import pandas as pd

fig, ax1 = plt.subplots(figsize=(10,5)) # Set proper size for the plot

# Specify which variables are needed for the singular line plot and mark each point with a dot
ax1.plot(df['month_year'], df['median_price_change_pct'], marker='o', color='blue', label='Price Change %') # Label the line
ax1.set_xlabel('Month') # Set label for x-axis
ax1.set_ylabel('Price Change %', color='blue') # Set label for one side of y-axis
ax1.tick_params(axis='y', labelcolor='blue') 

ax2 = ax1.twinx()
# Specify variables needed for the other singular line plot and mark each point with a dot
ax2.plot(df['month_year'], df['sentiment_score'], marker='x', color='orange', label='Sentiment Score') # Label the line
ax2.set_ylabel('Sentiment Score', color='orange') # Set the label for the other side of the y-axis
ax2.tick_params(axis='y', labelcolor='orange') # Make color different than the other line plot

plt.title("Median Price Change % vs Sentiment Over Time") # Set label for the whole graph
fig.autofmt_xdate() 
fig.tight_layout()
plt.savefig("price_change_vs_sentiment.png", dpi=300) # Save the figure as a png file to Jupyter Notebook
plt.show()
