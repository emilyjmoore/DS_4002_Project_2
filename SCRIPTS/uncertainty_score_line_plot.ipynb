# %%
# Import necessary packages
import pandas as pd
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5)) # Set size for the figure
# Specify the variables needed for the x and y axis, mark the points with a square, and make the line dashed
plt.plot(df['month_year'], df['uncertainty_score'], marker='s', linestyle='--', color='red') 
plt.title("Uncertainty Score Over Time") # Set decsriptive label for the figure
plt.xlabel("Month") # Label the x-axis
plt.ylabel("Uncertainty Score") # Label the y-axis
plt.grid(True) # Add grid to make points easily readable
plt.xticks(rotation=45)
plt.savefig("uncertainty_over_time.png", dpi=300) # Save the figure as a png file to Jupyter Notebook
plt.show()
