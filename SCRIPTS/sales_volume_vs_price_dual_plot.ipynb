# %%
# Import necessary packages
import pandas as pd
import matplotlib.pyplot as plt

fig, ax1 = plt.subplots(figsize=(10,5)) # Set size for the figure
# Specify variables for the x and y values, mark the points with a dot, line is green, and label the line
ax1.plot(df['month_year'], df['median_price'], marker='o', color='green', label='Median Price')
ax1.set_xlabel('Month') # Set label for x-axis
ax1.set_ylabel('Median Price ($)', color='green') # Set label for one side of y-axis
ax1.tick_params(axis='y', labelcolor='green') 

ax2 = ax1.twinx()
# Specify variables for the x and y values, mark the points with an arrow, color the line purple, and add label
ax2.plot(df['month_year'], df['sales_volume'], marker='^', color='purple', label='Sales Volume')
ax2.set_ylabel('Sales Volume', color='purple') # Set label for the other side of the y-axis
ax2.tick_params(axis='y', labelcolor='purple')

plt.title("Median Price and Sales Volume Over Time") # Set a title for the figure
fig.autofmt_xdate()
fig.tight_layout()
plt.savefig("sales_volume_vs_price.png", dpi=300) # Save the figure as a png file to Jupyter Notebook
plt.show()
